# %%
from __future__ import print_function
import sys
import os
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import os
import glob

#matplotlib.rcParams['savefig.dpi'] = 2 * matplotlib.rcParams['savefig.dpi'] # larger image
#matplotlib.rcParams['figure.figsize']= (20.0, 10.0) # larger image


print("Python version:\n{}\n".format(sys.version))
print("matplotlib version: {}".format(matplotlib.__version__))
print("pandas version: {}".format(pd.__version__))
print("numpy version: {}".format(np.__version__))
print("seaborn version: {}".format(sns.__version__))
# Out:
# Python version:
# 3.7.8 | packaged by conda-forge | (default, Jul 31 2020, 02:25:08)
# [GCC 7.5.0]
#
# matplotlib version: 3.3.3
# pandas version: 1.1.4
# numpy version: 1.19.4
# seaborn version: 0.11.0

# %%
90.9*33/31
# Out:
# 96.76451612903227

# %%
root_path = '../2-Run1'  # The path to the directory containing the systems

igbs = ['igb1', 'igb2', 'igb5', 'igb7', 'igb8']  # Each of the systems as named in their directory

ffs = ['ff94','ff96','ff98','ff99', 'ff99SB', 'ff99SBildn', 'ff99SBnmr', 'ff03.r1', 'ff14SB', \
       'ff14SBonlysc','ff14ipq','fb15','ff15ipq']  # The name of the state directories

filename_pattern = 'bend.dat'  # The glob to match the data files to read

dfs = {}  # Mapping of system name to list of state DataFrames

igbff_all = []
for ff in ffs:
    #igbff_all = []
    for igb in igbs:
        direc=igb + '_'+ ff
        # For each system and state, grab all the data files that match the glob
        file_glob = os.path.join(root_path, direc, filename_pattern)
        files = glob.glob(file_glob)
        for f in files:
            # Read each into a file to be put into a dict
            df = pd.read_csv(f, sep=r'\s+', skiprows=2501, names=['Frame', 'Fraction bend'])
            df['igbff'] = '{0} {1}'.format(ff, igb)
            igbff_all.append(df)
df_bend = pd.concat(igbff_all)

# %%
root_path = '../2-Run1'  # The path to the directory containing the systems

igbs = ['igb1', 'igb2', 'igb5', 'igb7', 'igb8']  # Each of the systems as named in their directory

ffs = ['ff94','ff96','ff98','ff99', 'ff99SB', 'ff99SBildn', 'ff99SBnmr', 'ff03.r1', 'ff14SB', \
       'ff14SBonlysc','ff14ipq','fb15','ff15ipq']  # The name of the state directories

filename_pattern = '310.dat'  # The glob to match the data files to read

dfs = {}  # Mapping of system name to list of state DataFrames

igbff_all = []
for ff in ffs:
    #igbff_all = []
    for igb in igbs:
        direc=igb + '_'+ ff
        # For each system and state, grab all the data files that match the glob
        file_glob = os.path.join(root_path, direc, filename_pattern)
        files = glob.glob(file_glob)
        for f in files:
            # Read each into a file to be put into a dict
            df = pd.read_csv(f, sep=r'\s+', skiprows=2501, names=['Frame', 'Fraction 310'])
            df['igbff'] = '{0} {1}'.format(ff, igb)
            igbff_all.append(df)
df_310 = pd.concat(igbff_all)

# %%
root_path = '../2-Run1'  # The path to the directory containing the systems

igbs = ['igb1', 'igb2', 'igb5', 'igb7', 'igb8']  # Each of the systems as named in their directory

ffs = ['ff94','ff96','ff98','ff99', 'ff99SB', 'ff99SBildn', 'ff99SBnmr', 'ff03.r1', 'ff14SB', \
       'ff14SBonlysc','ff14ipq','fb15','ff15ipq']  # The name of the state directories

filename_pattern = 'turn.dat'  # The glob to match the data files to read

dfs = {}  # Mapping of system name to list of state DataFrames

igbff_all = []
for ff in ffs:
    #igbff_all = []
    for igb in igbs:
        direc=igb + '_'+ ff
        # For each system and state, grab all the data files that match the glob
        file_glob = os.path.join(root_path, direc, filename_pattern)
        files = glob.glob(file_glob)
        for f in files:
            # Read each into a file to be put into a dict
            df = pd.read_csv(f, sep=r'\s+', skiprows=2501, names=['Frame', 'Fraction turn'])
            df['igbff'] = '{0} {1}'.format(ff, igb)
            igbff_all.append(df)
df_turn = pd.concat(igbff_all)

# %%
root_path = '../2-Run1'  # The path to the directory containing the systems

igbs = ['igb1', 'igb2', 'igb5', 'igb7', 'igb8']  # Each of the systems as named in their directory

ffs = ['ff94','ff96','ff98','ff99', 'ff99SB', 'ff99SBildn', 'ff99SBnmr', 'ff03.r1', 'ff14SB', \
       'ff14SBonlysc','ff14ipq','fb15','ff15ipq']  # The name of the state directories

filename_pattern = 'pi.dat'  # The glob to match the data files to read

dfs = {}  # Mapping of system name to list of state DataFrames

igbff_all = []
for ff in ffs:
    #igbff_all = []
    for igb in igbs:
        direc=igb + '_'+ ff
        # For each system and state, grab all the data files that match the glob
        file_glob = os.path.join(root_path, direc, filename_pattern)
        files = glob.glob(file_glob)
        for f in files:
            # Read each into a file to be put into a dict
            df = pd.read_csv(f, sep=r'\s+', skiprows=2501, names=['Frame', 'Fraction pi'])
            df['igbff'] = '{0} {1}'.format(ff, igb)
            igbff_all.append(df)
df_pi = pd.concat(igbff_all)

# %%
root_path = '../2-Run1'  # The path to the directory containing the systems

igbs = ['igb1', 'igb2', 'igb5', 'igb7', 'igb8']  # Each of the systems as named in their directory

ffs = ['ff94','ff96','ff98','ff99', 'ff99SB', 'ff99SBildn', 'ff99SBnmr', 'ff03.r1', 'ff14SB', \
       'ff14SBonlysc','ff14ipq','fb15','ff15ipq']  # The name of the state directories

filename_pattern = 'para.dat'  # The glob to match the data files to read

dfs = {}  # Mapping of system name to list of state DataFrames

igbff_all = []
for ff in ffs:
    #igbff_all = []
    for igb in igbs:
        direc=igb + '_'+ ff
        # For each system and state, grab all the data files that match the glob
        file_glob = os.path.join(root_path, direc, filename_pattern)
        files = glob.glob(file_glob)
        for f in files:
            # Read each into a file to be put into a dict
            df = pd.read_csv(f, sep=r'\s+', skiprows=2501, names=['Frame', 'Fraction para'])
            df['igbff'] = '{0} {1}'.format(ff, igb)
            igbff_all.append(df)
df_para = pd.concat(igbff_all)

# %%
root_path = '../2-Run1'  # The path to the directory containing the systems

igbs = ['igb1', 'igb2', 'igb5', 'igb7', 'igb8']  # Each of the systems as named in their directory

ffs = ['ff94','ff96','ff98','ff99', 'ff99SB', 'ff99SBildn', 'ff99SBnmr', 'ff03.r1', 'ff14SB', \
       'ff14SBonlysc','ff14ipq','fb15','ff15ipq']  # The name of the state directories

filename_pattern = 'helicity.dat'  # The glob to match the data files to read

dfs = {}  # Mapping of system name to list of state DataFrames

igbff_all = []
for ff in ffs:
    #igbff_all = []
    for igb in igbs:
        direc=igb + '_'+ ff
        # For each system and state, grab all the data files that match the glob
        file_glob = os.path.join(root_path, direc, filename_pattern)
        files = glob.glob(file_glob)
        for f in files:
            # Read each into a file to be put into a dict
            df = pd.read_csv(f, sep=r'\s+', skiprows=2501, names=['Frame', 'Fraction helicity'])
            df['igbff'] = '{0} {1}'.format(ff, igb)
            igbff_all.append(df)
df_alpha = pd.concat(igbff_all)

# %%
root_path = '../2-Run1'  # The path to the directory containing the systems

igbs = ['igb1', 'igb2', 'igb5', 'igb7', 'igb8']  # Each of the systems as named in their directory

ffs = ['ff94','ff96','ff98','ff99', 'ff99SB', 'ff99SBildn', 'ff99SBnmr', 'ff03.r1', 'ff14SB', \
       'ff14SBonlysc','ff14ipq','fb15','ff15ipq']  # The name of the state directories

filename_pattern = 'anti.dat'  # The glob to match the data files to read

dfs = {}  # Mapping of system name to list of state DataFrames

igbff_all = []
for ff in ffs:
    #igbff_all = []
    for igb in igbs:
        direc=igb + '_'+ ff
        # For each system and state, grab all the data files that match the glob
        file_glob = os.path.join(root_path, direc, filename_pattern)
        files = glob.glob(file_glob)
        for f in files:
            # Read each into a file to be put into a dict
            df = pd.read_csv(f, sep=r'\s+', skiprows=2501, names=['Frame', 'Fraction anti'])
            df['igbff'] = '{0} {1}'.format(ff, igb)
            igbff_all.append(df)
df_anti = pd.concat(igbff_all)

# %%
df_tot=df_alpha

df_tot['Fraction beta']=df_anti['Fraction anti']+df_para['Fraction para']

df_tot['Alpha helix'] = df_tot['Fraction helicity']*33/31
df_tot['3-10 helix'] = df_310['Fraction 310']*33/31
df_tot['Pi helix'] = df_pi['Fraction pi']*33/31
df_tot['Beta strand'] = df_tot['Fraction beta']*33/31
df_tot['Turn'] = df_turn['Fraction turn']*33/31
df_tot['Bend'] = df_bend['Fraction bend']*33/31
df_tot['Coil'] = 1-(df_tot['Beta strand']+df_tot['Alpha helix']+df_tot['3-10 helix']+df_tot['Turn']+
                   df_tot['Bend']+df_tot['Pi helix'])
df_tot['Other'] = 1-(df_tot['Beta strand']+df_tot['Alpha helix'] )

df_tot=df_tot.drop(['Frame','Fraction helicity','Fraction beta'], axis=1)

df_tot.head()
# Out:
#        igbff  Alpha helix  3-10 helix  Pi helix  Beta strand      Turn  Bend  \
# 0  ff94 igb1     0.870774         0.0       0.0          0.0  0.064935   0.0
# 1  ff94 igb1     0.935710         0.0       0.0          0.0  0.000000   0.0
# 2  ff94 igb1     0.902710         0.0       0.0          0.0  0.000000   0.0
# 3  ff94 igb1     0.870774         0.0       0.0          0.0  0.096871   0.0
# 4  ff94 igb1     0.902710         0.0       0.0          0.0  0.064935   0.0
#
#        Coil     Other
# 0  0.064290  0.129226
# 1  0.064290  0.064290
# 2  0.097290  0.097290
# 3  0.032355  0.129226
# 4  0.032355  0.097290

# %%
grouped=df_tot.groupby(['igbff'], sort=False)
grouped

# %%
mean = grouped.mean()
mean.head()
# Out:
#            Alpha helix  3-10 helix  Pi helix  Beta strand      Turn      Bend  \
# igbff
# ff94 igb1     0.729657    0.078180  0.000157     0.000001  0.123081  0.005367
# ff94 igb2     0.775512    0.058219  0.000130     0.000000  0.101501  0.004638
# ff94 igb5     0.824408    0.036658  0.000102     0.000000  0.079885  0.002479
# ff94 igb7     0.767284    0.063959  0.000060     0.000000  0.094547  0.004498
# ff94 igb8     0.794698    0.051751  0.000199     0.000000  0.095832  0.003344
#
#                Coil     Other
# igbff
# ff94 igb1  0.063556  0.270342
# ff94 igb2  0.060000  0.224488
# ff94 igb5  0.056467  0.175592
# ff94 igb7  0.069653  0.232716
# ff94 igb8  0.054176  0.205302

# %%
mean1=mean.drop(['3-10 helix','Turn','Bend','Pi helix','Coil'], axis=1)
mean1.head()
# Out:
#            Alpha helix  Beta strand     Other
# igbff
# ff94 igb1     0.729657     0.000001  0.270342
# ff94 igb2     0.775512     0.000000  0.224488
# ff94 igb5     0.824408     0.000000  0.175592
# ff94 igb7     0.767284     0.000000  0.232716
# ff94 igb8     0.794698     0.000000  0.205302

# %%
mean2=mean.drop(['Other',], axis=1)
mean2.head()
# Out:
#            Alpha helix  3-10 helix  Pi helix  Beta strand      Turn      Bend  \
# igbff
# ff94 igb1     0.729657    0.078180  0.000157     0.000001  0.123081  0.005367
# ff94 igb2     0.775512    0.058219  0.000130     0.000000  0.101501  0.004638
# ff94 igb5     0.824408    0.036658  0.000102     0.000000  0.079885  0.002479
# ff94 igb7     0.767284    0.063959  0.000060     0.000000  0.094547  0.004498
# ff94 igb8     0.794698    0.051751  0.000199     0.000000  0.095832  0.003344
#
#                Coil
# igbff
# ff94 igb1  0.063556
# ff94 igb2  0.060000
# ff94 igb5  0.056467
# ff94 igb7  0.069653
# ff94 igb8  0.054176

# %%
sns.set(context='paper', style='whitegrid', palette='deep', font='sans-serif',\
        font_scale=1, rc={'grid.linestyle': '--'})

ax=mean1.plot(kind='bar',ylim=(0, 1),figsize=(11, 5.5), legend=False, rot=90, stacked = True )
ax.set_ylabel('Fraction of secondary sructure')
ax.set_xlabel('Implicit solvent / force field combinations')
plt.axhline(y=96.76, ls=":", c=".5" ) # 90.9*33/31
plt.legend(loc='upper right')
plt.tight_layout()
plt.savefig('./plots/sec_struct_1.pdf')
plt.savefig('./plots/sec_struct_1.png', dpi=300)
#plt.show()

# %%
sns.set(context='paper', style='whitegrid', palette='deep', font='sans-serif',\
        font_scale=1, rc={'grid.linestyle': '--'})

ax=mean1.plot(kind='barh',xlim=(0, 1),figsize=(5.5, 11), legend=False, rot=0, stacked = True )
plt.gca().invert_yaxis()
ax.set_xlabel('Fraction of secondary sructure')
ax.set_ylabel('Implicit solvent / force field combinations')
plt.axvline(x=96.76, ls=":", c=".5" ) # 90.9*33/31
plt.legend(loc='lower right')
plt.tight_layout()
plt.savefig('./plots/sec_struct_2.pdf')
plt.savefig('./plots/sec_struct_2.png', dpi=300)
#plt.show()

# %%
pal = sns.color_palette("deep")
sns.palplot(pal)
print(pal.as_hex())
# Out:
# ['#4c72b0', '#dd8452', '#55a868', '#c44e52', '#8172b3', '#937860', '#da8bc3', '#8c8c8c', '#ccb974', '#64b5cd']

# %%
mypal=['#4c72b0','#8172b3', '#64b5cd', '#c44e52','#dd8452',  '#ccb974', '#55a868']
sns.palplot(mypal)

# %%
sns.set(context='paper', style='whitegrid', palette=mypal, font='sans-serif',\
        font_scale=1, rc={'grid.linestyle': '--'}, color_codes=False)

ax=mean2.plot(kind='bar',figsize=(11,5.5), ylim=(0, 1), legend=False, rot=90, stacked = True )
ax.set_ylabel('Fraction of secondary sructure')
ax.set_xlabel('Implicit solvent / force field combinations')
plt.axhline(y=96.76, ls=":", c=".5" ) # 90.9*33/31

plt.legend(loc='lower center', bbox_to_anchor=(0.52, 0.01))
plt.tight_layout()

plt.savefig('./plots/sec_struct_3.pdf')
plt.savefig('./plots/sec_struct_3.png', dpi=300)

# %%
sns.set(context='paper', style='whitegrid', palette=mypal, font='sans-serif',\
        font_scale=1, rc={'grid.linestyle': '--'}, color_codes=False)

ax=mean2.plot(kind='barh',xlim=(0, 1),figsize=(5.5, 11), legend=False, rot=0, stacked = True )
plt.gca().invert_yaxis()
ax.set_xlabel('Fraction of secondary sructure')
ax.set_ylabel('Implicit solvent / force field combinations')
plt.axvline(x=96.76, ls=":", c=".5" ) # 90.9*33/31
plt.legend(loc='lower center', bbox_to_anchor=(0.16, 0.36))
plt.tight_layout()

plt.savefig('./plots/sec_struct_4.pdf')
plt.savefig('./plots/sec_struct_4.png', dpi=300)

# %%
root_path = '../2-Run1'  # The path to the directory containing the systems

igbs = ['igb1', 'igb2', 'igb5', 'igb7', 'igb8']  # Each of the systems as named in their directory

ffs = ['ff94','ff96','ff98','ff99', 'ff99SB', 'ff99SBildn', 'ff99SBnmr', 'ff03.r1', 'ff14SB', \
       'ff14SBonlysc','ff14ipq','fb15','ff15ipq']  # The name of the state directories

filename_pattern = 'helicity.dat'  # The glob to match the data files to read

dfs = {}  # Mapping of system name to list of state DataFrames

igbff_all = []
mean=[]
std=[]
igbff=[]
igbl=[]
ffl=[]
for ff in ffs:
    for igb in igbs:
        direc=igb + '_'+ ff
        file_glob = os.path.join(root_path, direc, filename_pattern)
        files = glob.glob(file_glob)
        for f in files:
            df = pd.read_csv(f, sep=r'\s+', skiprows=2501,usecols=[1],names=['Fraction helicity'])
            df['helicity'] = df['Fraction helicity']*33/31*100
            df=df.drop('Fraction helicity',axis=1 )
            mean.append(df.mean()[0])
            std.append(df.std()[0])
            igbff.append('{0} {1}'.format(ff, igb))
            igbl.append(igb)
            ffl.append(ff)
            
mean_series = pd.Series(mean) 
std_series = pd.Series(std)
igbff_series = pd.Series(igbff)
igb_series = pd.Series(igbl)
ff_series = pd.Series(ffl)
  
frame = { 'Average helicity (%)': mean_series, 'Standard deviation': std_series,
        'igbff':igbff_series, 'igb':igb_series, 'ff':ff_series} 
  
df_helicity = pd.DataFrame(frame)             

df_helicity.head()
# Out:
#    Average helicity (%)  Standard deviation      igbff   igb    ff
# 0             72.965705           13.934443  ff94 igb1  igb1  ff94
# 1             77.551242           10.875522  ff94 igb2  igb2  ff94
# 2             82.440817            8.545134  ff94 igb5  igb5  ff94
# 3             76.728360           11.456565  ff94 igb7  igb7  ff94
# 4             79.469809           10.548812  ff94 igb8  igb8  ff94

# %%
sns.set(context='paper', style='whitegrid', palette="pastel", font='sans-serif',\
        font_scale=1.4, rc={'grid.linestyle': ''}, color_codes=False)

f, ax = plt.subplots(figsize=(10, 5.2))

ax = sns.scatterplot(x="ff", y="igb",
                     hue="Standard deviation", size="Average helicity (%)",
                     palette='GnBu_r', sizes=(5, 1000),
                     data=df_helicity)
sns.despine(left=True, bottom= True)
plt.legend(bbox_to_anchor=(1.1, 1), loc=2, borderaxespad=0., frameon=False, ncol=1, labelspacing=1.1,)
#ax.set_xticklabels(rotation=90)
plt.xticks(rotation=90)


ax.set_xlabel('Force field')
ax.set_ylabel('Implicit solvent')

plt.tight_layout()
# plt.savefig('./bubbleplot1.png', dpi=400)

# %%
frame2 = { 'Average helicity (%)': mean_series, 'Standard deviation': std_series,
        'igbff':igbff_series, 'igb':igb_series, 'ff':ff_series, 'avg': mean_series} 
  
df_helicity2 = pd.DataFrame(frame2)             

df_helicity2 = df_helicity2.round(1)

# %%
sns.set(context='paper', style='whitegrid', palette="pastel", font='sans-serif',\
        font_scale=1.4, rc={'grid.linestyle': ''}, color_codes=False)

f, ax = plt.subplots(figsize=(10, 5.2))

ax = sns.scatterplot(x="ff", y="igb",
                     hue="Standard deviation", size="Average helicity (%)",
                     palette='GnBu_r', sizes=(5, 1000),
                     data=df_helicity2)
sns.despine(left=True, bottom= True)
for line in range(0,df_helicity.shape[0]):
     ax.text(df_helicity2.ff[line], df_helicity2.igb[line], df_helicity2.avg[line], 
             horizontalalignment='center', 
             size='xx-small', color='black', weight='regular')
plt.legend(bbox_to_anchor=(1.1, 1), loc=2, borderaxespad=0., frameon=False, ncol=1, labelspacing=1.1,)
#ax.set_xticklabels(rotation=90)
plt.xticks(rotation=90)


ax.set_xlabel('Force field')
ax.set_ylabel('Implicit solvent')

plt.tight_layout()
# plt.savefig('./bubbleplot2.png', dpi=400)

# %%
sns.set(context='paper', style='whitegrid', palette="pastel", font='sans-serif',\
        font_scale=1.4, rc={'grid.linestyle': ''}, color_codes=False)

f, ax = plt.subplots(figsize=(10, 5.2))

ax = sns.scatterplot(x="ff", y="igb",
                     size="Standard deviation", hue="Average helicity (%)",
                     palette='GnBu', sizes=(10, 1000),
                     data=df_helicity)
sns.despine(left=True, bottom= True)
plt.legend(bbox_to_anchor=(1.1, 1), loc=2, borderaxespad=0., frameon=False, ncol=1, labelspacing=1.1,)
#ax.set_xticklabels(rotation=90)
plt.xticks(rotation=90)


ax.set_xlabel('Force field')
ax.set_ylabel('Implicit solvent')

plt.tight_layout()
# plt.savefig('./bubbleplot3.png', dpi=400)

# %%
a=df_helicity.pivot("igb", "ff", "Average helicity (%)")
a
# Out:
# ff         fb15    ff03.r1     ff14SB  ff14SBonlysc    ff14ipq    ff15ipq  \
# igb
# igb1   0.000000  83.877606  51.729817     30.228655  27.849841  47.449836
# igb2   0.000000  68.253658  58.084456     21.056192  31.076782  12.086251
# igb5   0.000000  70.592874  68.029057     27.859676  11.900459  45.604104
# igb7  28.764394  32.370301  18.241350      5.945358  16.823939   0.680644
# igb8   0.000000  79.325267  62.592739     25.040857  28.052901  32.514775
#
# ff         ff94       ff96       ff98       ff99     ff99SB  ff99SBildn  \
# igb
# igb1  72.965705  76.661273  78.826409  19.804362  29.558521   24.585357
# igb2  77.551242   2.386902  77.416586  32.494349  20.548514   19.224304
# igb5  82.440817  80.650028  82.342089  40.757111  33.664830   32.392711
# igb7  76.728360   0.046585  76.500767  22.384214   4.385575    4.538849
# igb8  79.469809   6.620150  79.616385  29.763684  25.917315   20.117879
#
# ff    ff99SBnmr
# igb
# igb1  78.624437
# igb2  83.336380
# igb5  86.877127
# igb7  78.469396
# igb8  83.085563

# %%
ffs = ['ff94','ff96','ff98','ff99', 'ff99SB', 'ff99SBildn', 'ff99SBnmr', 'ff03.r1', 'ff14SB', \
       'ff14SBonlysc','ff14ipq','fb15','ff15ipq']
a=a.reindex(ffs,axis=1)
a
# Out:
# ff         ff94       ff96       ff98       ff99     ff99SB  ff99SBildn  \
# igb
# igb1  72.965705  76.661273  78.826409  19.804362  29.558521   24.585357
# igb2  77.551242   2.386902  77.416586  32.494349  20.548514   19.224304
# igb5  82.440817  80.650028  82.342089  40.757111  33.664830   32.392711
# igb7  76.728360   0.046585  76.500767  22.384214   4.385575    4.538849
# igb8  79.469809   6.620150  79.616385  29.763684  25.917315   20.117879
#
# ff    ff99SBnmr    ff03.r1     ff14SB  ff14SBonlysc    ff14ipq       fb15  \
# igb
# igb1  78.624437  83.877606  51.729817     30.228655  27.849841   0.000000
# igb2  83.336380  68.253658  58.084456     21.056192  31.076782   0.000000
# igb5  86.877127  70.592874  68.029057     27.859676  11.900459   0.000000
# igb7  78.469396  32.370301  18.241350      5.945358  16.823939  28.764394
# igb8  83.085563  79.325267  62.592739     25.040857  28.052901   0.000000
#
# ff      ff15ipq
# igb
# igb1  47.449836
# igb2  12.086251
# igb5  45.604104
# igb7   0.680644
# igb8  32.514775

# %%
b=df_helicity.pivot("igb", "ff", "Standard deviation")
b=b.reindex(ffs,axis=1)

# %%
sns.set(context='paper', style='whitegrid', palette="pastel", font='sans-serif',\
        font_scale=1.4, rc={'grid.linestyle': ''}, color_codes=False)

f, ax = plt.subplots(figsize=(9, 4))
sns.heatmap(a, cmap='Blues',fmt='0.0f',annot=b, 
            cbar_kws={'label': 'Avergare helicity (%)'}, vmin=0.0, vmax=100.0)

ax.set_xlabel('Force field')
ax.set_ylabel('Implicit solvent')

plt.tight_layout()
# plt.savefig('./heatmap1.png', dpi=400)

# %%
sns.set(context='paper', style='whitegrid', palette="pastel", font='sans-serif',\
        font_scale=1.4, rc={'grid.linestyle': ''}, color_codes=False)

f, ax = plt.subplots(figsize=(9, 4))
sns.heatmap(a, cmap='Blues',fmt='0.0f',annot=False, 
            cbar_kws={'label': 'Average helicity (%)'}, vmin=0.0, vmax=100.0)
plt.gca().invert_yaxis()
ax.set_xlabel('Force field')
ax.set_ylabel('Implicit solvent')

plt.tight_layout()
plt.savefig('./plots/heatmap2.png', dpi=400)

# %%
sns.set(context='paper', style='whitegrid', palette="pastel", font='sans-serif',\
        font_scale=1.4, rc={'grid.linestyle': ''}, color_codes=False)

f, ax = plt.subplots(figsize=(9, 4))
sns.heatmap(a, cmap='Blues',fmt='0.0f',annot=True, 
            cbar_kws={'label': 'Avergare helicity (%)'}, vmin=0.0, vmax=100.0)
plt.gca().invert_yaxis()
ax.set_xlabel('Force field')
ax.set_ylabel('Implicit solvent')

plt.tight_layout()
# plt.savefig('./heatmap3.png', dpi=400)
